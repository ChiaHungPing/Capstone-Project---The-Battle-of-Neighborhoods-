# %% [markdown]
# # Capstone Project - Clustering Neighborhoods

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# * [Introduction](#Introduction)
# * [Data](#Data)
# * [Methodology](#Methodology)
# * [Finding](#Finding)
# * [Discussion](#Discussion)
# * [Conclusion](#Conclusion)

# %% [markdown]
# ## 1. Introduction <a name="Introduction"></a>

# %% [markdown]
# In this project, we will be grouping neighborhoods in Toronto into three clusters, neighborhoods in city center, in the middle of center and outer city, and outer part of the city by using the frequency of occurrence of types of retail store located around each neighborhood. Specifically, the report is targeting to both home buyers and investors whom are considering owning or investing a house in a neighborhood based on their preference on whether they prefer near or away from the city.
#
# Since there are multiple types of retail store that can be found in Toronto, we are only interested in shopping mall, plaza, supermarket, department store, and big box store for analysis. The frequency of occurrence of the top two shopping types as mentioned above will be characteristic of each neighborhood for clustering. The neighborhoods will then be plotted on the folium map for visualization.

# %% [markdown]
# ## 2. Data <a name="Data"></a>

# %% [markdown]
# In light of our goal, following data is needed for predictive analysis:
#
#   - Latitude, longitude and borough in which a neighborhood belongs to of each neighborhood
#   - Types of retail store that are shopping mall, plaza, supermarket, department store, and big box store located nearby of each neighborhood and their respective latitude and longitude
#
# These information will be sourced from Wikipedia, FourSquare and readily available Geocode package.

# %%
# Insta beautifulsoup package for WebScraping 
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Downloading https://files.pythonhosted.org/packages/d1/41/e6495bd7d3781cee623ce23ea6ac73282a373088fcd0ddc809a047b18eae/beautifulsoup4-4.9.3-py3-none-any.whl (115kB)
#      |████████████████████████████████| 122kB 39.1MB/s eta 0:00:01
# Collecting soupsieve>1.2; python_version >= "3.0" (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/36/69/d82d04022f02733bf9a72bc3b96332d360c0c5307096d76f6bb7489f7e57/soupsieve-2.2.1-py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.9.3 bs4-0.0.1 soupsieve-2.2.1

# %%
# Import the libraries for web scraping 
import numpy as np 
import pandas as pd 
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ### 2.1 - Explore Neighborhoods in Toronto

# %% [markdown]
# We will extract the information of postal code and borough in which a neighborhood belongs in for every neighborhood from Wikipedia using library of BeautifulSoup to perform web scrapping. Once these information have been scrapped, it will then be merged with the dataset of readily available Geocode package that contains information of latitude and longitude of each neighborhood.

# %%
# Neighborhoods in Toronto from Wikipedia 
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
html = requests.get(url).text

# %%
soup = BeautifulSoup(html, 'html5lib')

# %%
# Using beautifulsoup to scrape the data 
table_contents=[]
table=soup.find('table')
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell)

# print(table_contents)
df1=pd.DataFrame(table_contents)
df1['Borough']=df1['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})

# %%
# Extract the data of latitude and longitude of each neighborhood 
df = pd.read_csv('Geospatial_Coordinates.csv')

# %%
df.rename(columns={'Postal Code': 'PostalCode'}, inplace = True)

# %%
# Merging the two datasets from Wikipedia and Geocode package 
Toronto_df = pd.merge(df1, df, on=['PostalCode'])

# %%
Toronto_df
# Out:
#     PostalCode                Borough  \
# 0          M3A             North York
# 1          M4A             North York
# 2          M5A       Downtown Toronto
# 3          M6A             North York
# 4          M7A           Queen's Park
# ..         ...                    ...
# 98         M8X              Etobicoke
# 99         M4Y       Downtown Toronto
# 100        M7Y  East Toronto Business
# 101        M8Y              Etobicoke
# 102        M8Z              Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4                        Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100                                     Enclave of M4L  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %% [markdown]
# Together there are 5 columns of Postal Code, Borough, Neighborhood, Latitude and Longitude with 103 samples or neighborhoods can be identified in Toronto.

# %%
Toronto_df['Neighborhood'].count()
# Out:
# 103

# %%
# Number of neighborhoods under each borough 
Toronto_df['Borough'].value_counts()
# Out:
# North York                24
# Downtown Toronto          17
# Scarborough               17
# Etobicoke                 11
# Central Toronto            9
# West Toronto               6
# York                       5
# East Toronto               4
# East York                  4
# East Toronto Business      1
# Mississauga                1
# East York/East Toronto     1
# Downtown Toronto Stn A     1
# Etobicoke Northwest        1
# Queen's Park               1
# Name: Borough, dtype: int64

# %% [markdown]
# ### 2.2 - Plotting Each Neighborhood on Folum Map

# %%
# Install folium and geopy 
# !pip install folium
# !pip install geopy
# Out:
# Requirement already satisfied: folium in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.25.1)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (1.15.0)
# Requirement already satisfied: branca in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (0.4.2)
# Requirement already satisfied: jinja2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (3.0.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2->folium) (2.0.1)
# Collecting geopy
#   Downloading https://files.pythonhosted.org/packages/e1/e1/45f25e3d3acf26782888f847de7c958a2807a039210fb1016cc3fb9555c4/geopy-2.2.0-py3-none-any.whl (118kB)
#      |████████████████████████████████| 122kB 28.7MB/s eta 0:00:01
# Collecting geographiclib<2,>=1.49 (from geopy)
#   Downloading https://files.pythonhosted.org/packages/df/60/d1d4c4944f9726228faa80fbe2206c8ddfd9757791b2de2facb8818c5d74/geographiclib-1.52-py3-none-any.whl
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.52 geopy-2.2.0

# %%
from geopy.geocoders import Nominatim 
import folium 

import matplotlib.cm as cm 
import matplotlib.colors as colors 

from sklearn.cluster import KMeans

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="Toronto, Ontario")
location = geolocator.geocode(address)
latitude = location.latitude 
longitude = location.longitude

# %% [markdown]
# The markings of each neighborhood can be clearly seen on the folium map. Together there are 103 marking on the map.

# %%
Map_Toronto1 = folium.Map(location=[latitude,longitude], zoom_start = 11)

for lat, lng, label in zip (Toronto_df['Latitude'], Toronto_df['Longitude'], Toronto_df['Neighborhood']):
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup = label,
        color='blue',
        fill=True,
        fill_color = '#3186cc',
        fill_opacity = 0.7,
        parse_html = False).add_to(Map_Toronto1)

Map_Toronto1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_24258bdba6f748fe86bb359a3a1b1682%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_24258bdba6f748fe86bb359a3a1b1682%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_24258bdba6f748fe86bb359a3a1b1682%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_24258bdba6f748fe86bb359a3a1b1682%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6534817%2C-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### 2.3 - Explore the Retail Stores that are Nearby in Each Neighborhood

# %% [markdown]
# The next piece of information that we are interested in is types of retail store located nearby to each neighborhood and their respective latitude and longitude. This information will be obtained from FourSquare using API call. The radius will be set to 8km from the center grid of each neighborhood. Information that are not relevant being obtained under category id of 4bf58dd8d48988d1fd941735, category id assigned to Shopping Mall in FourSquare will be excluded from our analysis.

# %%
CLIENT_ID = '-'
CLIENT_SECRET = '-'
VERSION = '20210825'
radius = 8000
LIMIT = 100 
categoryId = '4bf58dd8d48988d1fd941735'

# %%
def getNearbyVenues(borough, neighborhood, latitudes, longitudes, radius=8000):
    
    venues_list=[]
    for borough, neighborhood, lat, lng in zip(borough, neighborhood, latitudes, longitudes):

        
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius,
            categoryId,
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            borough,
            neighborhood,
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name']) for v in results])


    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Borough',
                  'Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue',
                             
                  'Venue Latitude', 
                  'Venue Longitude',
                  'Venue Category']
           
    
    return(nearby_venues)

# %% [markdown]
# Let's apply the above created function on Toronto neighborhoods.

# %%
Toronto_venues1 = getNearbyVenues(borough = Toronto_df['Borough'],
                                neighborhood = Toronto_df['Neighborhood'],
                                latitudes = Toronto_df['Latitude'],
                                longitudes = Toronto_df['Longitude']
                            )
Toronto_venues1
# Out:
#          Borough                                       Neighborhood  \
# 0     North York                                          Parkwoods
# 1     North York                                          Parkwoods
# 2     North York                                          Parkwoods
# 3     North York                                          Parkwoods
# 4     North York                                          Parkwoods
# ...          ...                                                ...
# 4999   Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
# 5000   Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
# 5001   Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
# 5002   Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
# 5003   Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
#
#       Neighborhood Latitude  Neighborhood Longitude                    Venue  \
# 0                 43.753259              -79.329656    CF Shops at Don Mills
# 1                 43.753259              -79.329656         CF Fairview Mall
# 2                 43.753259              -79.329656          Bayview Village
# 3                 43.753259              -79.329656  Scarborough Town Centre
# 4                 43.753259              -79.329656          Leaside Village
# ...                     ...                     ...                      ...
# 4999              43.628841              -79.520999                Sino Mall
# 5000              43.628841              -79.520999             Petro-Canada
# 5001              43.628841              -79.520999           Crossways Mall
# 5002              43.628841              -79.520999       BlackBerry Tahoe B
# 5003              43.628841              -79.520999                  Walmart
#
#       Venue Latitude  Venue Longitude Venue Category
# 0          43.735011       -79.344787  Shopping Mall
# 1          43.777981       -79.344397  Shopping Mall
# 2          43.768527       -79.385494  Shopping Mall
# 3          43.775277       -79.257413  Shopping Mall
# 4          43.705682       -79.360777  Shopping Mall
# ...              ...              ...            ...
# 4999       43.597794       -79.594803  Shopping Mall
# 5000       43.636354       -79.475463    Gas Station
# 5001       43.656775       -79.452498  Shopping Mall
# 5002       43.638382       -79.607973         Office
# 5003       43.656229       -79.435530  Big Box Store
#
# [5004 rows x 8 columns]

# %% [markdown]
# Let's check how many types of venue were obtained from FourSquare. Types of venue that are not relevant to our analysis will be excluded from the data set.

# %%
Toronto_venues1['Venue Category'].value_counts()
# Out:
# Shopping Mall             3999
# Clothing Store             131
# Plaza                      101
# Pharmacy                    93
# Office                      93
# Supermarket                 72
# Grocery Store               71
# Department Store            53
# Big Box Store               50
# Women's Store               49
# General Travel              43
# Building                    42
# Miscellaneous Shop          41
# Shoe Store                  38
# Gas Station                 36
# Accessories Store           27
# Mobile Phone Shop           21
# Furniture / Home Store      21
# Electronics Store           16
# Shopping Plaza               4
# Jewelry Store                3
# Name: Venue Category, dtype: int64

# %% [markdown]
# ### 2.4 - Data Preparation

# %% [markdown]
# As mentioned earlier that we are only interested in shopping mall, plaza, supermarket, department store and big box store nearby to each neighborhood for our analysis, others will be excluded from the dataset.

# %%
Toronto_Shop = Toronto_venues1[Toronto_venues1['Venue Category'].isin(['Shopping Mall', 'Plaza','Supermarket','Department Store','Big Box Store'])]
Toronto_Shop
# Out:
#          Borough                                       Neighborhood  \
# 0     North York                                          Parkwoods
# 1     North York                                          Parkwoods
# 2     North York                                          Parkwoods
# 3     North York                                          Parkwoods
# 4     North York                                          Parkwoods
# ...          ...                                                ...
# 4997   Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
# 4998   Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
# 4999   Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
# 5001   Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
# 5003   Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
#
#       Neighborhood Latitude  Neighborhood Longitude                     Venue  \
# 0                 43.753259              -79.329656     CF Shops at Don Mills
# 1                 43.753259              -79.329656          CF Fairview Mall
# 2                 43.753259              -79.329656           Bayview Village
# 3                 43.753259              -79.329656   Scarborough Town Centre
# 4                 43.753259              -79.329656           Leaside Village
# ...                     ...                     ...                       ...
# 4997              43.628841              -79.520999  Galleria Shopping Centre
# 4998              43.628841              -79.520999             Rockwood Mall
# 4999              43.628841              -79.520999                 Sino Mall
# 5001              43.628841              -79.520999            Crossways Mall
# 5003              43.628841              -79.520999                   Walmart
#
#       Venue Latitude  Venue Longitude Venue Category
# 0          43.735011       -79.344787  Shopping Mall
# 1          43.777981       -79.344397  Shopping Mall
# 2          43.768527       -79.385494  Shopping Mall
# 3          43.775277       -79.257413  Shopping Mall
# 4          43.705682       -79.360777  Shopping Mall
# ...              ...              ...            ...
# 4997       43.667592       -79.442053  Shopping Mall
# 4998       43.625328       -79.604702  Shopping Mall
# 4999       43.597794       -79.594803  Shopping Mall
# 5001       43.656775       -79.452498  Shopping Mall
# 5003       43.656229       -79.435530  Big Box Store
#
# [4275 rows x 8 columns]

# %%
# Number of stores under each retail store type 
Toronto_Shop['Venue Category'].value_counts()
# Out:
# Shopping Mall       3999
# Plaza                101
# Supermarket           72
# Department Store      53
# Big Box Store         50
# Name: Venue Category, dtype: int64

# %%
Toronto_Shop.groupby(['Borough','Neighborhood','Venue Category']).count()
# Out:
#                                                                 Neighborhood Latitude  \
# Borough         Neighborhood                  Venue Category
# Central Toronto Davisville                    Big Box Store                         1
#                                               Department Store                      1
#                                               Plaza                                 2
#                                               Shopping Mall                        56
#                                               Supermarket                           1
# ...                                                                               ...
# York            Humewood-Cedarvale            Shopping Mall                        49
#                                               Supermarket                           1
#                 Runnymede, The Junction North Big Box Store                         1
#                                               Shopping Mall                        33
#                 Weston                        Shopping Mall                        25
#
#                                                                 Neighborhood Longitude  \
# Borough         Neighborhood                  Venue Category
# Central Toronto Davisville                    Big Box Store                          1
#                                               Department Store                       1
#                                               Plaza                                  2
#                                               Shopping Mall                         56
#                                               Supermarket                            1
# ...                                                                                ...
# York            Humewood-Cedarvale            Shopping Mall                         49
#                                               Supermarket                            1
#                 Runnymede, The Junction North Big Box Store                          1
#                                               Shopping Mall                         33
#                 Weston                        Shopping Mall                         25
#
#                                                                 Venue  \
# Borough         Neighborhood                  Venue Category
# Central Toronto Davisville                    Big Box Store         1
#                                               Department Store      1
#                                               Plaza                 2
#                                               Shopping Mall        56
#                                               Supermarket           1
# ...                                                               ...
# York            Humewood-Cedarvale            Shopping Mall        49
#                                               Supermarket           1
#                 Runnymede, The Junction North Big Box Store         1
#                                               Shopping Mall        33
#                 Weston                        Shopping Mall        25
#
#                                                                 Venue Latitude  \
# Borough         Neighborhood                  Venue Category
# Central Toronto Davisville                    Big Box Store                  1
#                                               Department Store               1
#                                               Plaza                          2
#                                               Shopping Mall                 56
#                                               Supermarket                    1
# ...                                                                        ...
# York            Humewood-Cedarvale            Shopping Mall                 49
#                                               Supermarket                    1
#                 Runnymede, The Junction North Big Box Store                  1
#                                               Shopping Mall                 33
#                 Weston                        Shopping Mall                 25
#
#                                                                 Venue Longitude
# Borough         Neighborhood                  Venue Category
# Central Toronto Davisville                    Big Box Store                   1
#                                               Department Store                1
#                                               Plaza                           2
#                                               Shopping Mall                  56
#                                               Supermarket                     1
# ...                                                                         ...
# York            Humewood-Cedarvale            Shopping Mall                  49
#                                               Supermarket                     1
#                 Runnymede, The Junction North Big Box Store                   1
#                                               Shopping Mall                  33
#                 Weston                        Shopping Mall                  25
#
# [328 rows x 5 columns]

# %% [markdown]
# Now, we are going to identify the top two types of retail store that are frequently occurred in a neighborhood. Before that we will have to create dummy variable for each retail store type as the analysis requires integer or floating type of data.

# %%
Toronto_onehot = pd.get_dummies(Toronto_Shop[['Venue Category']], prefix="", prefix_sep="")

# Adding back the columns of Neighborhood, Borough, and Venue to the newly created data frame, Toronto_onehot 
Toronto_onehot['Neighborhood'] = Toronto_Shop['Neighborhood']

Toronto_onehot['Borough'] = Toronto_Shop['Borough']

Toronto_onehot['Venue'] = Toronto_Shop['Venue'] 

# Setting the the first three columns with Neighborhood comes first followed by Borough and Venue 
fixed_columns = list(Toronto_onehot.columns[-3:]) + list(Toronto_onehot.columns[:-3])

Toronto_onehot = Toronto_onehot[fixed_columns]

Toronto_onehot
# Out:
#                                            Neighborhood     Borough  \
# 0                                             Parkwoods  North York
# 1                                             Parkwoods  North York
# 2                                             Parkwoods  North York
# 3                                             Parkwoods  North York
# 4                                             Parkwoods  North York
# ...                                                 ...         ...
# 4997  Mimico NW, The Queensway West, South of Bloor,...   Etobicoke
# 4998  Mimico NW, The Queensway West, South of Bloor,...   Etobicoke
# 4999  Mimico NW, The Queensway West, South of Bloor,...   Etobicoke
# 5001  Mimico NW, The Queensway West, South of Bloor,...   Etobicoke
# 5003  Mimico NW, The Queensway West, South of Bloor,...   Etobicoke
#
#                          Venue  Big Box Store  Department Store  Plaza  \
# 0        CF Shops at Don Mills              0                 0      0
# 1             CF Fairview Mall              0                 0      0
# 2              Bayview Village              0                 0      0
# 3      Scarborough Town Centre              0                 0      0
# 4              Leaside Village              0                 0      0
# ...                        ...            ...               ...    ...
# 4997  Galleria Shopping Centre              0                 0      0
# 4998             Rockwood Mall              0                 0      0
# 4999                 Sino Mall              0                 0      0
# 5001            Crossways Mall              0                 0      0
# 5003                   Walmart              1                 0      0
#
#       Shopping Mall  Supermarket
# 0                 1            0
# 1                 1            0
# 2                 1            0
# 3                 1            0
# 4                 1            0
# ...             ...          ...
# 4997              1            0
# 4998              1            0
# 4999              1            0
# 5001              1            0
# 5003              0            0
#
# [4275 rows x 8 columns]

# %% [markdown]
# Let's group by borough followed by neighborhood and by taking the mean of the frequency of occurrence of each category.

# %%
Toronto_grouped = Toronto_onehot.groupby(['Borough','Neighborhood']).mean().reset_index()
Toronto_grouped
# Out:
#              Borough                                      Neighborhood  \
# 0    Central Toronto                                        Davisville
# 1    Central Toronto                                  Davisville North
# 2    Central Toronto                          Forest Hill North & West
# 3    Central Toronto                                     Lawrence Park
# 4    Central Toronto                       Moore Park, Summerhill East
# ..               ...                                               ...
# 98              York                               Caledonia-Fairbanks
# 99              York  Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 100             York                                Humewood-Cedarvale
# 101             York                     Runnymede, The Junction North
# 102             York                                            Weston
#
#      Big Box Store  Department Store     Plaza  Shopping Mall  Supermarket
# 0         0.016393          0.016393  0.032787       0.918033     0.016393
# 1         0.015873          0.015873  0.031746       0.920635     0.015873
# 2         0.018182          0.018182  0.036364       0.909091     0.018182
# 3         0.000000          0.000000  0.018182       0.963636     0.018182
# 4         0.017857          0.017857  0.035714       0.928571     0.000000
# ..             ...               ...       ...            ...          ...
# 98        0.018868          0.018868  0.037736       0.905660     0.018868
# 99        0.027027          0.000000  0.027027       0.918919     0.027027
# 100       0.018519          0.018519  0.037037       0.907407     0.018519
# 101       0.029412          0.000000  0.000000       0.970588     0.000000
# 102       0.000000          0.000000  0.000000       1.000000     0.000000
#
# [103 rows x 7 columns]

# %%
Toronto_grouped.shape
# Out:
# (103, 7)

# %% [markdown]
# We will now identify the top two shopping type for each neighborhood based on the frequency of the occurrence.

# %%
num_top_venues = 2 

for hood in Toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = Toronto_grouped[Toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[2:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq':2})

    print(temp.sort_values('freq',ascending=False).reset_index(drop=True).head(num_top_venues))
# Out:
# ----Davisville----
#            venue  freq
# 0  Shopping Mall  0.92
# 1          Plaza  0.03
# ----Davisville North----
#            venue  freq
# 0  Shopping Mall  0.92
# 1          Plaza  0.03
# ----Forest Hill North & West----
#            venue  freq
# 0  Shopping Mall  0.91
# 1          Plaza  0.04
# ----Lawrence Park----
#            venue  freq
# 0  Shopping Mall  0.96
# 1          Plaza  0.02
# ----Moore Park, Summerhill East----
#            venue  freq
# 0  Shopping Mall  0.93
# 1          Plaza  0.04
# ----North Toronto West----
#            venue  freq
# 0  Shopping Mall  0.91
# 1          Plaza  0.04
# ----Roselawn----
#            venue  freq
# 0  Shopping Mall  0.91
# 1          Plaza  0.03
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#            venue  freq
# 0  Shopping Mall  0.90
# 1          Plaza  0.04
# ----The Annex, North Midtown, Yorkville----
#            venue  freq
# 0  Shopping Mall  0.90
# 1          Plaza  0.04
# ----Berczy Park----
#            venue  freq
# 0  Shopping Mall  0.88
# 1          Plaza  0.05
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#            venue  freq
# 0  Shopping Mall  0.91
# 1  Big Box Store  0.03
# ----Central Bay Street----
#            venue  freq
# 0  Shopping Mall  0.89
# 1          Plaza  0.05
# ----Christie----
#            venue  freq
# 0  Shopping Mall  0.90
# 1          Plaza  0.04
# ----Church and Wellesley----
#            venue  freq
# 0  Shopping Mall  0.89
# 1          Plaza  0.04
# ----Commerce Court, Victoria Hotel----
#            venue  freq
# 0  Shopping Mall  0.88
# 1          Plaza  0.05
# ----First Canadian Place, Underground city----
#            venue  freq
# 0  Shopping Mall  0.88
# 1          Plaza  0.05
# ----Garden District, Ryerson----
#            venue  freq
# 0  Shopping Mall  0.89
# 1          Plaza  0.05
# ----Harbourfront East, Union Station, Toronto Islands----
#            venue  freq
# 0  Shopping Mall  0.88
# 1          Plaza  0.05
# ----Kensington Market, Chinatown, Grange Park----
#            venue  freq
# 0  Shopping Mall  0.89
# 1          Plaza  0.04
# ----Regent Park, Harbourfront----
#            venue  freq
# 0  Shopping Mall  0.88
# 1          Plaza  0.05
# ----Richmond, Adelaide, King----
#            venue  freq
# 0  Shopping Mall  0.89
# 1          Plaza  0.05
# ----Rosedale----
#            venue  freq
# 0  Shopping Mall  0.90
# 1          Plaza  0.04
# ----St. James Town----
#            venue  freq
# 0  Shopping Mall  0.88
# 1          Plaza  0.05
# ----St. James Town, Cabbagetown----
#            venue  freq
# 0  Shopping Mall  0.89
# 1          Plaza  0.04
# ----Toronto Dominion Centre, Design Exchange----
#            venue  freq
# 0  Shopping Mall  0.88
# 1          Plaza  0.05
# ----University of Toronto, Harbord----
#            venue  freq
# 0  Shopping Mall  0.90
# 1          Plaza  0.04
# ----Enclave of M5E----
#            venue  freq
# 0  Shopping Mall  0.88
# 1          Plaza  0.05
# ----India Bazaar, The Beaches West----
#            venue  freq
# 0  Shopping Mall  0.90
# 1          Plaza  0.05
# ----Studio District----
#            venue  freq
# 0  Shopping Mall  0.88
# 1          Plaza  0.05
# ----The Beaches----
#               venue  freq
# 0     Shopping Mall  0.93
# 1  Department Store  0.03
# ----The Danforth West, Riverdale----
#            venue  freq
# 0  Shopping Mall  0.90
# 1          Plaza  0.04
# ----Enclave of M4L----
#            venue  freq
# 0  Shopping Mall  0.90
# 1          Plaza  0.05
# ----Leaside----
#            venue  freq
# 0  Shopping Mall  0.93
# 1          Plaza  0.03
# ----Parkview Hill, Woodbine Gardens----
#            venue  freq
# 0  Shopping Mall  0.93
# 1          Plaza  0.05
# ----Thorncliffe Park----
#            venue  freq
# 0  Shopping Mall  0.91
# 1          Plaza  0.04
# ----Woodbine Heights----
#            venue  freq
# 0  Shopping Mall  0.91
# 1          Plaza  0.04
# ----The Danforth  East----
#            venue  freq
# 0  Shopping Mall  0.92
# 1          Plaza  0.04
# ----Alderwood, Long Branch----
#            venue  freq
# 0  Shopping Mall  0.93
# 1  Big Box Store  0.04
# ----Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood----
#            venue  freq
# 0  Shopping Mall  0.94
# 1  Big Box Store  0.03
# ----Islington Avenue----
#            venue  freq
# 0  Shopping Mall  0.93
# 1  Big Box Store  0.03
# ----Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West----
#            venue  freq
# 0  Shopping Mall  0.93
# 1  Big Box Store  0.04
# ----New Toronto, Mimico South, Humber Bay Shores----
#            venue  freq
# 0  Shopping Mall  0.90
# 1  Big Box Store  0.05
# ----Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East----
#            venue  freq
# 0  Shopping Mall  0.92
# 1  Big Box Store  0.04
# ----South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----The Kingsway, Montgomery Road, Old Mill North----
#            venue  freq
# 0  Shopping Mall  0.92
# 1  Big Box Store  0.04
# ----West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale----
#               venue  freq
# 0     Shopping Mall  0.96
# 1  Department Store  0.04
# ----Westmount----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Enclave of L4W----
#            venue  freq
# 0  Shopping Mall  0.94
# 1  Big Box Store  0.03
# ----Bathurst Manor, Wilson Heights, Downsview North----
#            venue  freq
# 0  Shopping Mall  0.92
# 1    Supermarket  0.05
# ----Bayview Village----
#            venue  freq
# 0  Shopping Mall  0.98
# 1    Supermarket  0.02
# ----Bedford Park, Lawrence Manor East----
#            venue  freq
# 0  Shopping Mall  0.96
# 1          Plaza  0.02
# ----Don Mills North----
#            venue  freq
# 0  Shopping Mall  0.94
# 1    Supermarket  0.04
# ----Don Mills South----
#            venue  freq
# 0  Shopping Mall  0.96
# 1          Plaza  0.02
# ----Downsview Central----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Downsview East----
#            venue  freq
# 0  Shopping Mall  0.92
# 1    Supermarket  0.05
# ----Downsview Northwest----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Downsview West----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Fairview, Henry Farm, Oriole----
#            venue  freq
# 0  Shopping Mall  0.99
# 1    Supermarket  0.01
# ----Glencairn----
#            venue  freq
# 0  Shopping Mall  0.92
# 1          Plaza  0.04
# ----Hillcrest Village----
#            venue  freq
# 0  Shopping Mall  0.99
# 1    Supermarket  0.01
# ----Humber Summit----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Humberlea, Emery----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Lawrence Manor, Lawrence Heights----
#            venue  freq
# 0  Shopping Mall  0.92
# 1  Big Box Store  0.03
# ----North Park, Maple Leaf Park, Upwood Park----
#            venue  freq
# 0  Shopping Mall  0.90
# 1  Big Box Store  0.03
# ----Northwood Park, York University----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Parkwoods----
#            venue  freq
# 0  Shopping Mall  0.95
# 1    Supermarket  0.03
# ----Victoria Village----
#            venue  freq
# 0  Shopping Mall  0.94
# 1    Supermarket  0.04
# ----Willowdale South----
#            venue  freq
# 0  Shopping Mall  0.94
# 1    Supermarket  0.04
# ----Willowdale West----
#            venue  freq
# 0  Shopping Mall  0.98
# 1    Supermarket  0.02
# ----Willowdale, Newtonbrook----
#            venue  freq
# 0  Shopping Mall  0.98
# 1    Supermarket  0.02
# ----York Mills West----
#            venue  freq
# 0  Shopping Mall  0.94
# 1    Supermarket  0.04
# ----York Mills, Silver Hills----
#            venue  freq
# 0  Shopping Mall  0.95
# 1    Supermarket  0.03
# ----Ontario Provincial Government----
#            venue  freq
# 0  Shopping Mall  0.89
# 1          Plaza  0.04
# ----Agincourt----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Birch Cliff, Cliffside West----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Cedarbrae----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Clarks Corners, Tam O'Shanter, Sullivan----
#            venue  freq
# 0  Shopping Mall  0.98
# 1    Supermarket  0.02
# ----Cliffside, Cliffcrest, Scarborough Village West----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Dorset Park, Wexford Heights, Scarborough Town Centre----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Golden Mile, Clairlea, Oakridge----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Guildwood, Morningside, West Hill----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Kennedy Park, Ionview, East Birchmount Park----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Malvern, Rouge----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Milliken, Agincourt North, Steeles East, L'Amoreaux East----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Rouge Hill, Port Union, Highland Creek----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Scarborough Village----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Steeles West, L'Amoreaux West----
#            venue  freq
# 0  Shopping Mall  0.99
# 1    Supermarket  0.01
# ----Upper Rouge----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Wexford, Maryvale----
#            venue  freq
# 0  Shopping Mall  0.98
# 1    Supermarket  0.02
# ----Woburn----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0
# ----Brockton, Parkdale Village, Exhibition Place----
#            venue  freq
# 0  Shopping Mall  0.92
# 1  Big Box Store  0.03
# ----Dufferin, Dovercourt Village----
#            venue  freq
# 0  Shopping Mall  0.89
# 1          Plaza  0.04
# ----High Park, The Junction South----
#            venue  freq
# 0  Shopping Mall  0.90
# 1          Plaza  0.04
# ----Little Portugal, Trinity----
#            venue  freq
# 0  Shopping Mall  0.88
# 1          Plaza  0.05
# ----Parkdale, Roncesvalles----
#            venue  freq
# 0  Shopping Mall  0.89
# 1          Plaza  0.04
# ----Runnymede, Swansea----
#            venue  freq
# 0  Shopping Mall  0.94
# 1  Big Box Store  0.03
# ----Caledonia-Fairbanks----
#            venue  freq
# 0  Shopping Mall  0.91
# 1          Plaza  0.04
# ----Del Ray, Mount Dennis, Keelsdale and Silverthorn----
#            venue  freq
# 0  Shopping Mall  0.92
# 1  Big Box Store  0.03
# ----Humewood-Cedarvale----
#            venue  freq
# 0  Shopping Mall  0.91
# 1          Plaza  0.04
# ----Runnymede, The Junction North----
#            venue  freq
# 0  Shopping Mall  0.97
# 1  Big Box Store  0.03
# ----Weston----
#            venue  freq
# 0  Shopping Mall   1.0
# 1  Big Box Store   0.0

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[2:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
Toronto_venues_sorted = pd.DataFrame(columns=columns)
Toronto_venues_sorted['Neighborhood'] = Toronto_grouped['Neighborhood']

for ind in np.arange(Toronto_grouped.shape[0]):
    Toronto_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)

Toronto_venues_sorted
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 0                                          Davisville         Shopping Mall
# 1                                    Davisville North         Shopping Mall
# 2                            Forest Hill North & West         Shopping Mall
# 3                                       Lawrence Park         Shopping Mall
# 4                         Moore Park, Summerhill East         Shopping Mall
# ..                                                ...                   ...
# 98                                Caledonia-Fairbanks         Shopping Mall
# 99   Del Ray, Mount Dennis, Keelsdale and Silverthorn         Shopping Mall
# 100                                Humewood-Cedarvale         Shopping Mall
# 101                     Runnymede, The Junction North         Shopping Mall
# 102                                            Weston         Shopping Mall
#
#     2nd Most Common Venue
# 0                   Plaza
# 1                   Plaza
# 2                   Plaza
# 3             Supermarket
# 4                   Plaza
# ..                    ...
# 98                  Plaza
# 99            Supermarket
# 100                 Plaza
# 101         Big Box Store
# 102           Supermarket
#
# [103 rows x 3 columns]

# %% [markdown]
# ## 3. Methodology <a name="Methodology"></a>

# %% [markdown]
# ### 3.1 - K-Nearest Clustering

# %% [markdown]
# The main function of the K-nearest clustering technique is to cluster neighborhoods that have similar characteristic into clusters of neighborhoods. As mentioned in the beginning that we will use the top two retail store types based on the frequency of occurrence as the characteristic for clustering. The three clusters are the clusters that are at the center, in between the center and outer, and outer. These three clusters will then be plotted on the folium map.
#
# TheK-nearest clustering technique is perform in the following steps:
#  -  As we have identified the top two retail store types located within 8km radius from the grid center of the neighborhood, we will now use the information to cluster into three clusters by setting the number of clusters to 3
#  -  Once performing the K-nearest function, each neighborhood will be assigned a label range from 0 to 2
#  -  This information will then be used to plot on the folium map

# %%
kclusters = 3 
Toronto_grouped_clustering = Toronto_grouped.drop(['Borough','Neighborhood'], 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)
kmeans.labels_[0:3]
# Out:
# array([2, 2, 1], dtype=int32)

# %%
# Insert the Cluster Labels in new columns 
Toronto_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# Create a new dataframe 
Toronto_Neigh = Toronto_df

# Merge the dataframe with venues characteristics for each neighborhood with dataframe that has the information regarding the neighborhood 
Toronto_Neigh = Toronto_Neigh.join(Toronto_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

Toronto_Neigh.head()
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront  43.654260
# 3        M6A        North York  Lawrence Manor, Lawrence Heights  43.718518
# 4        M7A      Queen's Park     Ontario Provincial Government  43.662301
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue
# 0 -79.329656               2         Shopping Mall           Supermarket
# 1 -79.315572               2         Shopping Mall           Supermarket
# 2 -79.360636               1         Shopping Mall                 Plaza
# 3 -79.464763               2         Shopping Mall           Supermarket
# 4 -79.389494               1         Shopping Mall                 Plaza

# %%
# The dataset has 103 neighborhoods which is same as the number of samples in the raw data 
Toronto_Neigh
# Out:
#     PostalCode                Borough  \
# 0          M3A             North York
# 1          M4A             North York
# 2          M5A       Downtown Toronto
# 3          M6A             North York
# 4          M7A           Queen's Park
# ..         ...                    ...
# 98         M8X              Etobicoke
# 99         M4Y       Downtown Toronto
# 100        M7Y  East Toronto Business
# 101        M8Y              Etobicoke
# 102        M8Z              Etobicoke
#
#                                           Neighborhood   Latitude  Longitude  \
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4                        Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100                                     Enclave of M4L  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
#      Cluster Labels 1st Most Common Venue 2nd Most Common Venue
# 0                 2         Shopping Mall           Supermarket
# 1                 2         Shopping Mall           Supermarket
# 2                 1         Shopping Mall                 Plaza
# 3                 2         Shopping Mall           Supermarket
# 4                 1         Shopping Mall                 Plaza
# ..              ...                   ...                   ...
# 98                2         Shopping Mall      Department Store
# 99                1         Shopping Mall                 Plaza
# 100               1         Shopping Mall                 Plaza
# 101               2         Shopping Mall      Department Store
# 102               2         Shopping Mall      Department Store
#
# [103 rows x 8 columns]

# %% [markdown]
# ## 4. Finding <a name="Finding"></a>

# %% [markdown]
# The three clusters are plotted on the folium map. Based on the markings plotted on the folium map, it can be clearly seen that neighborhoods in the purple cluster located in the center of the Toronto, light green at the middle of center and outer and red is outer.

# %%
map_clusters1 = folium.Map(location=[latitude, longitude], zoom_start=11)

# Set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_Neigh['Latitude'], Toronto_Neigh['Longitude'], Toronto_Neigh['Neighborhood'], Toronto_Neigh['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=8,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters1)
       
map_clusters1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_b755bea89a264b9884157f1d8b14a7fd%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b755bea89a264b9884157f1d8b14a7fd%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b755bea89a264b9884157f1d8b14a7fd%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_b755bea89a264b9884157f1d8b14a7fd%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6534817%2C-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
Toronto_Neigh["Cluster Labels"].value_counts()
# Out:
# 1    40
# 0    34
# 2    29
# Name: Cluster Labels, dtype: int64

# %% [markdown]
# ## 5. Discussion <a name="Discussion"></a>

# %% [markdown]
# The report has successfully grouping neighborhoods into clusters of neighborhoods at the center, in between center and outer, and outer city. There are 40 neighborhoods are located at the center city, 29 at the middle in between center and outer and 34 at the outer city. The analysis is useful for investors and home buyers to decide which neighborhood that they will choose based on the preference of location. It can as well be an indicator or as a proxy to measure the relative average housing price. For instance, on average, housing price in neighborhoods that are located in purple cluster is higher than average housing price located in both light green and red.

# %% [markdown]
# ## 6. Conclusion <a name="Conclusion"></a>

# %% [markdown]
# The business problem of helping to locate neighborhoods that are in the center, in between center and outer, and outer Toronto city has been addressed. The analysis report not only helping investors and home buyers to identify the neighborhood location whether be in city center or outer as well could use this finding of the report could act as a reference or a proxy to measure the relative average housing price between the 'clusters' of neighborhoods. The final decision will still on investor and home buyer regarding which neighborhood they are interested in.

# %% [markdown]
# ## THE END
